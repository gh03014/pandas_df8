# %%
#fas-정재환
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import numpy as np
import csv
import json
import seaborn as sns
# %matplotlib inline

# %%
#한글 폰트 적용 - 한글깨짐 방지
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
plt.rcParams['axes.unicode_minus'] = False

# %%
df = pd.read_csv('2017국민건강검진.csv')
df
# Out:
#        Unnamed: 0  연령   신장  체중  허리둘레  수축기혈압  이완기혈압  식전혈당(공복혈당)  총콜레스테롤  흡연상태  \
# 0               0  40  170  75  90.0  120.0   80.0        99.0   193.0   1.0
# 1               1  35  180  80  89.0  130.0   82.0       106.0   228.0   3.0
# 2               2  45  165  75  91.0  120.0   70.0        98.0   136.0   1.0
# 3               3  55  175  80  91.0  145.0   87.0        95.0   201.0   1.0
# 4               4  55  165  60  80.0  138.0   82.0       101.0   199.0   1.0
# ...           ...  ..  ...  ..   ...    ...    ...         ...     ...   ...
# 49995       49995  50  175  85  95.0  143.0  103.0       105.0   201.0   3.0
# 49996       49996  65  170  70  79.0  105.0   58.0        94.0   295.0   2.0
# 49997       49997  60  165  50  74.0  130.0   80.0       106.0   216.0   3.0
# 49998       49998  50  155  50  75.0  135.0   85.0        91.0   231.0   1.0
# 49999       49999  40  165  55  76.0  140.0   90.0        79.0   141.0   1.0
#
#        음주여부
# 0       1.0
# 1       0.0
# ...

# %%
# scatter산점도, x축, y축, 그룹화
fig = plt.figure(figsize=(9,8), facecolor='linen')
#add_axes를 이용한 plot 가로, 세로 크기 설정
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8])
sns.scatterplot(x="식전혈당(공복혈당)", y="총콜레스테롤", hue='체중', data = df, ax=ax)
plt.xlabel('식전혈당(공복혈당)')
plt.ylabel('총콜레스테롤')
plt.title('콜레스테롤, 혈당별  체중분포')
plt.show()

# %%
# scatter산점도, x축, y축, 그룹화
fig = plt.figure(figsize=(9,8), facecolor='linen')
#add_axes를 이용한 plot 가로, 세로 크기 설정
ax = fig.add_axes([0.1, 0.1, 0.7, 0.7])
sns.scatterplot(x="식전혈당(공복혈당)", y="총콜레스테롤", hue='체중', data = df, ax=ax)
ax.set_xlabel('식전혈당(공복혈당)')
ax.set_ylabel('총콜레스테롤')
#font_size를 이용한 라벨 텍스트 크기설정
ax.set_title('콜레스테롤, 혈당별  체중분포', fontsize=30)
plt.show()

# %%
# scatter산점도, x축, y축, 그룹화
fig = plt.figure(figsize=(9,8), facecolor='linen')
#add_axes를 이용한 plot 가로, 세로 크기 설정
ax = fig.add_axes([0.1, 0.1, 0.7, 0.7])
sns.scatterplot(x="식전혈당(공복혈당)", y="총콜레스테롤", hue='체중', data = df, ax=ax)
ax.set_xlabel('식전혈당(공복혈당)')
ax.set_ylabel('총콜레스테롤')
#y속성을 이용해 title라벨의 y좌표 위치 설정
ax.set_title('콜레스테롤, 혈당별  체중분포', fontsize=30, y=0)
plt.show()

# %%
# scatter산점도, x축, y축, 그룹화
fig = plt.figure(figsize=(9,8), facecolor='linen')
#add_axes를 이용한 plot 가로, 세로 크기 설정
ax = fig.add_axes([0.1, 0.1, 0.7, 0.7])
sns.scatterplot(x="식전혈당(공복혈당)", y="총콜레스테롤", hue='체중', data = df, ax=ax)
ax.set_xlabel('식전혈당(공복혈당)')
ax.set_ylabel('총콜레스테롤')
#font_size를 이용한 라벨 텍스트 크기설정
#y속성을 이용해 title라벨의 y좌표 위치 설정
ax.set_title('콜레스테롤, 혈당별  체중분포', fontsize=30, y=0.5)
plt.show()

# %%
# scatter산점도, x축, y축, 그룹화
fig = plt.figure(figsize=(9,8), facecolor='linen')
#add_axes를 이용한 plot 가로, 세로 크기 설정
ax = fig.add_axes([0.1, 0.1, 0.7, 0.7])
sns.scatterplot(x="식전혈당(공복혈당)", y="총콜레스테롤", hue='체중', data = df, ax=ax)
ax.set_xlabel('식전혈당(공복혈당)')
ax.set_ylabel('총콜레스테롤')
#font_size를 이용한 라벨 텍스트 크기설정
#y속성을 이용해 title라벨의 y좌표 위치 설정
ax.set_title('콜레스테롤, 혈당별  체중분포', fontsize=30, y=-0.2)
plt.show()

# %%
# scatter산점도, x축, y축, 그룹화
fig = plt.figure(figsize=(9,8), facecolor='linen')
#add_axes를 이용한 plot 가로, 세로 크기 설정
ax = fig.add_axes([0.1, 0.1, 0.7, 0.7])
sns.scatterplot(x="식전혈당(공복혈당)", y="총콜레스테롤", hue='체중', data = df, ax=ax)
ax.set_xlabel('식전혈당(공복혈당)')
ax.set_ylabel('총콜레스테롤')
# font_size를 이용한 라벨 텍스트 크기설정
# y속성을 이용해 title라벨의 y좌표 위치 설정
ax.set_title('콜레스테롤, 혈당별  체중분포', fontsize=30, y=-0.2)
#tick_params를 이용해 x축 단위 라벨 크기 설정
ax.tick_params(labelsize=20)
plt.show()

# %%
# scatter산점도, x축, y축, 그룹화
fig = plt.figure(figsize=(9,8), facecolor='linen')
#add_axes를 이용한 plot 가로, 세로 크기 설정
ax = fig.add_axes([0.1, 0.1, 0.7, 0.7])
sns.scatterplot(x="식전혈당(공복혈당)", y="총콜레스테롤", hue='체중', data = df, ax=ax)
ax.set_xlabel('식전혈당(공복혈당)')
ax.set_ylabel('총콜레스테롤')
# font_size를 이용한 라벨 텍스트 크기설정
# y속성을 이용해 title라벨의 y좌표 위치 설정
ax.set_title('콜레스테롤, 혈당별  체중분포', fontsize=30, y=-0.2)
#tick_params를 이용해 x축 단위 라벨 크기 설정
#tick_params를 이용해 x축 좌표의 단위 라벨을 윗부분에 배치
ax.tick_params(labelsize=20, bottom=False, labelbottom=False, top=True, labeltop=True)
plt.show()

# %%
# scatter산점도, x축, y축, 그룹화
fig = plt.figure(figsize=(9,8), facecolor='linen')
#add_axes를 이용한 plot 가로, 세로 크기 설정
ax = fig.add_axes([0.1, 0.1, 0.7, 0.7])
sns.scatterplot(x="식전혈당(공복혈당)", y="총콜레스테롤", hue='체중', data = df, ax=ax)
ax.set_xlabel('식전혈당(공복혈당)')
ax.set_ylabel('총콜레스테롤')
# font_size를 이용한 라벨 텍스트 크기설정
# y속성을 이용해 title라벨의 y좌표 위치 설정
ax.set_title('콜레스테롤, 혈당별  체중분포', fontsize=30, y=-0.2)
#tick_params를 이용해 x축 단위 라벨 크기 설정
#tick_params를 이용해 좌표의 단위 라벨 위치 설정
ax.tick_params(labelsize=20, bottom=False, labelbottom=False, top=True, labeltop=True,
              left=False, labelleft=False, right=True, labelright=True)
plt.show()

# %%
# scatter산점도, x축, y축, 그룹화
fig = plt.figure(figsize=(9,8), facecolor='linen')
#add_axes를 이용한 plot 가로, 세로 크기 설정
ax = fig.add_axes([0.1, 0.1, 0.7, 0.7])
sns.scatterplot(x="식전혈당(공복혈당)", y="총콜레스테롤", hue='체중', data = df, ax=ax)
ax.set_xlabel('식전혈당(공복혈당)')
ax.set_ylabel('총콜레스테롤')
# font_size를 이용한 라벨 텍스트 크기설정
# y속성을 이용해 title라벨의 y좌표 위치 설정
ax.set_title('콜레스테롤, 혈당별  체중분포', fontsize=30, y=-0.2)
#tick_params를 이용해 x축 단위 라벨 크기 설정
#tick_params를 이용해 좌표의 단위 라벨 위치 설정
#tick_params의 location을 이용해 좌표의 단위 라벨 각도 설정
#tick_params의 axis를 이용해 x, y좌표중에 적용대상을 선택할 수 있다
ax.tick_params(axis='x', labelsize=20, bottom=False, labelbottom=False, top=True, labeltop=True,
              length=10, width=3, rotation=45)
ax.tick_params(axis='y', labelsize=20, left=False, labelleft=False, right=True, labelright=True, 
               length=10, width=3, rotation=45)
plt.show()
